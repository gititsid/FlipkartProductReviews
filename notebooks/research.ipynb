# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen
import logging

# %%
flipcart_url = "https://www.flipkart.com/search?q=" + "tv"

# %%
flipcart_url
# Out:
# 'https://www.flipkart.com/search?q=tv'

# %%
urlclient = urlopen(flipcart_url)

# %%
flipcart_page = urlclient.read()

# %%
flipcart_html = bs(flipcart_page , 'html.parser')

# %%
"https://www.flipkart.com"+"/dyanora-sigma-108-cm-43-inch-full-hd-led-smart-linux-tv-40-watt-box-speakers-bezel-less-design/p/itmcdbced04b2319?pid=TVSGHZAGFYKGZQ8K&lid=LSTTVSGHZAGFYKGZQ8KUAM8H1&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_1&otracker=search&otracker1=search&fm=organic&iid=en_xF8tH%2FD493QWU9p74CMkRhAnl%2FZDSt2g4RX8asyXf547oHm6aKW0Vwig1Ae%2FF%2BxpMab4jOA70lzjnpWCWaM8Dw%3D%3D&ppt=sp&ppn=sp&ssid=6vokrwan280000001676982936780&qH=c9a1fdac6e082dd8"
# Out:
# 'https://www.flipkart.com/dyanora-sigma-108-cm-43-inch-full-hd-led-smart-linux-tv-40-watt-box-speakers-bezel-less-design/p/itmcdbced04b2319?pid=TVSGHZAGFYKGZQ8K&lid=LSTTVSGHZAGFYKGZQ8KUAM8H1&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_1&otracker=search&otracker1=search&fm=organic&iid=en_xF8tH%2FD493QWU9p74CMkRhAnl%2FZDSt2g4RX8asyXf547oHm6aKW0Vwig1Ae%2FF%2BxpMab4jOA70lzjnpWCWaM8Dw%3D%3D&ppt=sp&ppn=sp&ssid=6vokrwan280000001676982936780&qH=c9a1fdac6e082dd8'

# %%
bigboxes = flipcart_html.find_all("div" ,{"class":"cPHDOP col-12-12"} )

# %%
len(bigboxes)
# Out:
# 30

# %%
bigboxes = bigboxes[2:]

# %%
productlink = "https://www.flipkart.com" + bigboxes[0].div.div.div.a['href']

# %%
for bigbox in bigboxes:
    try:
        print("https://www.flipkart.com" + bigbox.div.div.div.a['href'])
    except Exception as error:
        print("Some error")
        pass
# Out:
# https://www.flipkart.com/motorola-envisionx-140-cm-55-inch-qled-ultra-hd-4k-smart-google-tv-dolby-vision-atmos/p/itm1cfe8a61a68c5?pid=TVSGSRQ9SXPXPTXJ&lid=LSTTVSGSRQ9SXPXPTXJW7XESH&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_1&otracker=search&fm=organic&iid=en_Wvml99hoVlu2k92ml48svsCvLqWkUO1z5WTlcSt66PrES00qFBdJNV3mRBMtX1heakgg2_kBKEtHaClI-bQujg%3D%3D&ppt=None&ppn=None&ssid=hsqtm9wsv40000001717499965476&qH=c9a1fdac6e082dd8
# https://www.flipkart.com/motorola-envisionx-165-cm-65-inch-qled-ultra-hd-4k-smart-google-tv-dolby-vision-atmos/p/itm767828569c629?pid=TVSGRTDDGYA4HPWU&lid=LSTTVSGRTDDGYA4HPWUZVEWYT&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_2&otracker=search&fm=organic&iid=en_Wvml99hoVlu2k92ml48svsCvLqWkUO1z5WTlcSt66Pp0cVxUqmYMACtP8gwbILyiBEGVamGnnw0j4lFCO6ml8A%3D%3D&ppt=None&ppn=None&ssid=hsqtm9wsv40000001717499965476&qH=c9a1fdac6e082dd8
# ...

# %%
productlink
# Out:
# 'https://www.flipkart.com/motorola-envisionx-140-cm-55-inch-qled-ultra-hd-4k-smart-google-tv-dolby-vision-atmos/p/itm1cfe8a61a68c5?pid=TVSGSRQ9SXPXPTXJ&lid=LSTTVSGSRQ9SXPXPTXJW7XESH&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_1&otracker=search&fm=organic&iid=en_Wvml99hoVlu2k92ml48svsCvLqWkUO1z5WTlcSt66PrES00qFBdJNV3mRBMtX1heakgg2_kBKEtHaClI-bQujg%3D%3D&ppt=None&ppn=None&ssid=hsqtm9wsv40000001717499965476&qH=c9a1fdac6e082dd8'

# %%
procuct_req = urlopen(productlink)

# %%
product_html = bs(procuct_req, 'html.parser')

# %%
product_html
# Out:
# <!DOCTYPE html>
# ...

# %%
coment_box = product_html.find_all("div",{"class":"RcXBOT"})

# %%
len(coment_box)
# Out:
# 11

# %%
coment_box[0]
# Out:
# <div class="RcXBOT"><div class="col"><div class="col EPCmJX"><div class="row"><div class="XQDdHH Ga3i8K">4<img class="Rza2QY" src="..."/></div><p class="z9E0IG">Worth the money</p></div><div class="row"><div class="ZmyHeo"><div><div class="">Value for money but with some compromise<br><br>Pros : <br/>Price, <br/>Sharpness.<br/><br/>Cons: <br/>Screen bleeding.</br></br></div><span class="wTYmpv"><span>READ MORE</span></span></div></div></div><div class="xmAgz5 pVVA7t"><div class="Be4x5X d517go" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_c194f0b730574415b3fafb13a2be0ae4.jpeg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="Be4x5X d517go" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_4e05d9e1e1164095ab338d5a5e250240.jpeg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="Be4x5X d517go" style="background-image:url(https://rukminim1.f
# ...

# %%
reviewer = coment_box[0].div.div.find_all("p",{"class":"_2NsDsF AwS1CA"})[0].text

reviewer
# Out:
# 'NarasimhaRao Chennuru'

# %%
for a_box in coment_box:
    try:
        reviewer = a_box.div.div.find_all("p",{"class":"_2NsDsF AwS1CA"})[0].text
        print(reviewer)
    except Exception as e:
        print("Some error")
        pass
# Out:
# NarasimhaRao Chennuru
# Vishav Insan
# Muhammed Irshad
# Swarup Ranjan Biswal
# Debashis Das
# Prashant Kumbhar
# Rakhi Kumari
# Hussain Reddy Polu
# A K M  Abdullah
# anjineyulu yadav yadav
# Some error

# %%
for a_box in coment_box:
    try:
        rating = a_box.div.div.div.div.text
        print(rating)
    except Exception as e:
        print("Some erroe")
        pass
# Out:
# 4
# 5
# 3
# 5
# 3
# 5
# 4
# 4
# 5
# 5
# Some erroe

# %%
review_text = coment_box[0].div.div.div.p.text
review_text
# Out:
# 'Worth the money'

# %%
for a_box in coment_box:
    try:
        review_title = a_box.div.div.div.p.text
        print(review_title)
    except Exception as e:
        print("some error")
        pass
# Out:
# Worth the money
# Terrific purchase
# Does the job
# Awesome
# Average picture, good sound but does not meet expectation
# Fabulous!
# Very Good
# Nice product
# Worth every penny
# Worth every penny
# some error

# %%
review_text = coment_box[0].div.div.find_all("div",{"class":""})[0].text

review_text
# Out:
# 'Value for money but with some compromisePros : Price, Sharpness.Cons: Screen bleeding.READ MORE'

# %%
for a_box in coment_box:
    try:
        review_text = a_box.div.div.find_all("div",{"class":""})[0].text
        print(review_text)
    except Exception as e:
        print("some error")
        pass
# Out:
# Value for money but with some compromisePros : Price, Sharpness.Cons: Screen bleeding.READ MORE
# Very Good TV In This Price I Bought It For 38k In Big Billion Sale On Bajaj Finserv Very Good Sound And Picture Quality For 65 Inch Go For It Amazing Also Made In India !!!READ MORE
# First of all i get my delivery but the product was broken but they will replace it and i got a new one that was nice and the clarity was greatREAD MORE
# Awesome 😎READ MORE
# Ordered the TV on 09th Feb and the TV got delivered on 10th feb and the installation was done by the service person on 10th Feb itself.I can quote excellent as far as speed of delivery and installation is concerned.Coming to picture quality.....Very very average picture quality. It was inferior to my previous non-4K Kodak TV. Secondly there is no option to stretch video to fit the screen, which was available in my previous TV. I will rate 2 out of 5 as far as picture quality is concerned...READ MORE
# ...

# %%
reviews = [
    {'A': 1, 'B': 2},
    {'A': 3, 'B': 4}
]

# %%
import pandas as pd

# %%
df.head()
# Out:
#    A  B
# 0  1  2
# 1  3  4

# %%
df = pd.DataFrame(reviews)

# %%
df.to_csv('reviews.csv', index=False)
